# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(0, '/home/jovyan/mne-python/')
sys.path.insert(0, '/home/jovyan/braindecode/')

# %%
import pandas as pd

# %%
df = pd.read_csv('/home/jovyan/workspace-tuh-abnormal-analysis/TUH_EEG_DESCRIPTION.csv', index_col=0)

# %%
df
# Out:
#                                                     path version  year  month  \
# 0      /home/jovyan/mne_data/TUH/tuh_eeg/v1.1.0/edf/0...  v1.1.0  2002      9
# 1      /home/jovyan/mne_data/TUH/tuh_eeg/v1.1.0/edf/0...  v1.1.0  2002      9
# 2      /home/jovyan/mne_data/TUH/tuh_eeg/v1.1.0/edf/0...  v1.1.0  2002      9
# 3      /home/jovyan/mne_data/TUH/tuh_eeg/v1.1.0/edf/0...  v1.1.0  2002      9
# 4      /home/jovyan/mne_data/TUH/tuh_eeg/v1.1.0/edf/0...  v1.1.0  2002      9
# ...                                                  ...     ...   ...    ...
# 69577  /home/jovyan/mne_data/TUH/tuh_eeg/v1.2.0/edf/0...  v1.2.0  2017      3
# 69578  /home/jovyan/mne_data/TUH/tuh_eeg/v1.2.0/edf/0...  v1.2.0  2017      3
# 69579  /home/jovyan/mne_data/TUH/tuh_eeg/v1.2.0/edf/0...  v1.2.0  2017      3
# 69580  /home/jovyan/mne_data/TUH/tuh_eeg/v1.2.0/edf/0...  v1.2.0  2017      3
# 69581  /home/jovyan/mne_data/TUH/tuh_eeg/v1.2.0/edf/0...  v1.2.0  2017      3
#
# ...

# %% [raw]
# df.groupby('subject').head(1).gender.value_counts()

# %%
df['pathological'] = True

# %%
from decode_tueg import age_pyramid

# %%
ax = age_pyramid(
    df_of_ages_genders_and_pathology_status=df, 
    train_or_eval='',
    ylim=1500,
    fs=20,
    show_title=False,
    show_pathology_legend=False,
)
ax[0].get_figure().savefig('/home/jovyan/tuh_eeg.png', dpi=300, bbox_inches='tight')
