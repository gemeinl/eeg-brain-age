# %%
# !conda install -n brain_age -y pytorch cudatoolkit=11.3 -c pytorch
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/lukas/miniconda3/envs/brain_age
#
#   added / updated specs:
#     - cudatoolkit=11.3
#     - pytorch
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cudatoolkit-11.3.1         |       h2bc3f7f_2       549.3 MB
#     ------------------------------------------------------------
#                                            Total:       549.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   cudatoolkit        pkgs/main/linux-64::cudatoolkit-11.3.1-h2bc3f7f_2
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2022.1.0-h9e868ea_3769
#   mkl                pkgs/main/linux-64::mkl-2022.1.0-hc2b9512_224
#   pytorch            pytorch/linux-64::pytorch-1.13.1-py3.8_cpu_0
# ...

# %%
# !conda install -y scikit-learn -c conda-forge
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/lukas/miniconda3/envs/brain_age
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     joblib-1.2.0               |     pyhd8ed1ab_0         205 KB  conda-forge
#     libblas-3.9.0              |   16_linux64_mkl          13 KB  conda-forge
#     libcblas-3.9.0             |   16_linux64_mkl          12 KB  conda-forge
#     libgfortran-ng-12.2.0      |      h69a702a_19          22 KB  conda-forge
#     libgfortran5-12.2.0        |      h337968e_19         1.8 MB  conda-forge
#     liblapack-3.9.0            |   16_linux64_mkl          12 KB  conda-forge
#     numpy-1.22.3               |   py38h99721a1_2         6.8 MB  conda-forge
#     scikit-learn-0.24.2        |   py38hacb3eff_1         7.6 MB  conda-forge
# ...

# %%
# !conda install -y pandas
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/lukas/miniconda3/envs/brain_age
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bottleneck-1.3.5           |   py38h7deecbd_0         115 KB
#     fftw-3.3.9                 |       h27cfd23_1         2.3 MB
#     intel-openmp-2021.4.0      |    h06a4308_3561         4.2 MB
#     mkl-2021.4.0               |     h06a4308_640       142.6 MB
#     mkl-service-2.4.0          |   py38h7f8727e_0          59 KB
#     mkl_fft-1.3.1              |   py38hd3c417c_0         180 KB
#     mkl_random-1.2.2           |   py38h51133e4_0         308 KB
#     numexpr-2.8.4              |   py38he184ba9_0         134 KB
#     numpy-1.23.5               |   py38h14f4228_0          10 KB
#     numpy-base-1.23.5          |   py38h31eccc5_0         6.7 MB
# ...

# %%
# !conda install -y seaborn -c conda-forge
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/lukas/miniconda3/envs/brain_age
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cycler-0.11.0              |     pyhd8ed1ab_0          10 KB  conda-forge
#     jpeg-9e                    |       h166bdaf_1         268 KB  conda-forge
#     kiwisolver-1.4.4           |   py38h6a678d5_0          76 KB
#     libpng-1.6.37              |       hbc83047_0         278 KB
#     libtiff-4.0.10             |    hc3755c2_1005         602 KB  conda-forge
#     lz4-c-1.9.3                |       h9c3ff4c_1         179 KB  conda-forge
#     matplotlib-base-3.4.3      |   py38hf4fb855_1         7.3 MB  conda-forge
#     patsy-0.5.3                |     pyhd8ed1ab_0         189 KB  conda-forge
# ...

# %%
# !pip install skorch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.7/193.7 kB 700.1 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 684.1 kB/s eta 0:00:001m714.3 kB/s eta 0:00:01
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# braindecode 0.5.1 requires h5py, which is not installed.
# braindecode 0.5.1 requires mne, which is not installed.
# ...

# %%
# !conda install -y mne -c conda-forge
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/lukas/miniconda3/envs/brain_age
#
#   added / updated specs:
#     - mne
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |       2_kmp_llvm           6 KB  conda-forge
#     aom-3.5.0                  |       h27087fc_0         2.7 MB  conda-forge
#     appdirs-1.4.4              |     pyh9f0ad1d_0          13 KB  conda-forge
#     blosc-1.21.3               |       hafa529b_0          39 KB  conda-forge
#     brotli-1.0.9               |       h166bdaf_8          18 KB  conda-forge
#     brotli-bin-1.0.9           |       h166bdaf_8          20 KB  conda-forge
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
#     c-ares-1.18.1              |       h7f98852_0         113 KB  conda-forge
# ...

# %%
"hi"
# Out:
# 'hi'
